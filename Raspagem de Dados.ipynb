# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Lista de códigos
codigos = [
    "MT-5103858-A5D392DF73984B7E8F2DF104C1D7F2CE",
    "MT-5106307-684CFDC4C60A4BDDA189B2EB2AB7C10E",
    "MT-5103858-BED9C95936414FA19B57D0438DCB29B4"
]

# Função para obter o nome a partir do código
def obter_nome_por_codigo(codigo):
    url = f"https://www.google.com.br/search?q={codigo}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    # Encontrar a tag span com o texto desejado
    span = soup.find("span", string=re.compile(r"cadastrado por"))
    if span:
        match = re.search(r"cadastrado por\s+(.*?)[,\s]", span.text)
        if match:
            nome = match.group(1)
            return nome.strip()

    # Se o primeiro padrão não encontrar, tentar o segundo padrão
    span2 = soup.find("span", string=re.compile(r"cadastro ambiental rural de"))
    if span2:
        match2 = re.search(r"cadastro ambiental rural de nº.*?, cadastrado por\s+(.*?)[,\s]", span2.text)
        if match2:
            nome = match2.group(1)
            return nome.strip()

    return "Nome não encontrado"

# Criar lista de tuplas (codigo, nome)
dados = [(codigo, obter_nome_por_codigo(codigo)) for codigo in codigos]

# Converter para DataFrame do pandas
df = pd.DataFrame(dados, columns=["Código", "Nome"])

# Salvar em uma planilha
df.to_excel("nomes.xlsx", index=False)

# %%
# !pip install googlesearch-python
# Out:
# Collecting googlesearch-python
#   Downloading googlesearch-python-1.2.3.tar.gz (3.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.9 in c:\users\bernardo\anaconda 2\lib\site-packages (from googlesearch-python) (4.12.2)
# Requirement already satisfied: requests>=2.20 in c:\users\bernardo\anaconda 2\lib\site-packages (from googlesearch-python) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bernardo\anaconda 2\lib\site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bernardo\anaconda 2\lib\site-packages (from requests>=2.20->googlesearch-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bernardo\anaconda 2\lib\site-packages (from requests>=2.20->googlesearch-python) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bernardo\anaconda 2\lib\site-packages (from requests>=2.20->googlesearch-python) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bernardo\anaconda 2\lib\site-packages (from requests>=2.20->googlesearch-python) (2023.7.22)
# Building wheels for collected packages: googlesearch-python
#   Building wheel for googlesearch-python (setup.py): started
#   Building wheel for googlesearch-python (setup.py): finished with status 'done'
#   Created wheel for googlesearch-python: filename=googlesearch_python-1.2.3-py3-none-any.whl size=4224 sha256=7de1690a7d815b07b8b5051a7cc986b083f3046476e11aa344b70ad092e3333a
#   Stored in directory: c:\users\bernardo\appdata\local\pip\cache\wheels\c3\a9\82\de72a96d14538012479281dfda86c35b6da183692b94f45818
# Successfully built googlesearch-python
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.2.3

# %%
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Lista de códigos
codigos = [
    "MT-5103858-A5D392DF73984B7E8F2DF104C1D7F2CE",
    "MT-5106307-684CFDC4C60A4BDDA189B2EB2AB7C10E",
    "MT-5103858-BED9C95936414FA19B57D0438DCB29B4"
]

# Função para obter o nome a partir do código
def obter_nome_por_codigo(codigo):
    url = f"https://www.google.com.br/search?q={codigo}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")
    # Encontrar a tag span com o texto desejado
    span = soup.find("span", string=re.compile(r"cadastrado por"))
    if span:
        match = re.search(r"cadastrado por\s+(.*?)[,\s]", span.text)
        if match:
            nome = match.group(1)
            return nome.strip()

    # Se o primeiro padrão não encontrar, tentar o segundo padrão
    span2 = soup.find("span", string=re.compile(r"cadastro ambiental rural de"))
    if span2:
        match2 = re.search(r"cadastro ambiental rural de nº.*?, cadastrado por\s+(.*?)[,\s]", span2.text)
        if match2:
            nome = match2.group(1)
            return nome.strip()

    return "Nome não encontrado"

# Criar lista de tuplas (codigo, nome)
dados = [(codigo, obter_nome_por_codigo(codigo)) for codigo in codigos]

# Converter para DataFrame do pandas
df = pd.DataFrame(dados, columns=["Código", "Nome"])

# Salvar em uma planilha
df.to_excel("nomes.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 27
#      24     return "Nome não encontrado"
#      26 # Criar lista de tuplas (codigo, nome)
# ---> 27 dados = [(codigo, obter_nome_por_codigo(codigo)) for codigo in codigos]
#      29 # Converter para DataFrame do pandas
#      30 df = pd.DataFrame(dados, columns=["Código", "Nome"])
#
# Cell In[11], line 27, in <listcomp>(.0)
#      24     return "Nome não encontrado"
#      26 # Criar lista de tuplas (codigo, nome)
# ---> 27 dados = [(codigo, obter_nome_por_codigo(codigo)) for codigo in codigos]
#      29 # Converter para DataFrame do pandas
#      30 df = pd.DataFrame(dados, columns=["Código", "Nome"])
#
# Cell In[11], line 16, in obter_nome_por_codigo(codigo)
#      14 def obter_nome_por_codigo(codigo):
#      15     query = f"{codigo} cadastrado por"
# ---> 16     for j in search(query, num=1, stop=1, pause=2):
#      17         if "googleusercontent" not in j:
#      18             response = requests.get(j)
#
# TypeError: search() got an unexpected keyword argument 'num'

# %%
import requests
from bs4 import BeautifulSoup

def obter_nome_por_codigo(codigo):
    link = f"https://www.google.com.br/search?q={codigo}"
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
    }

    requisicao = requests.get(link, headers=headers)
    if requisicao.status_code == 200:
        site = BeautifulSoup(requisicao.content, "html.parser")
        # Encontra a primeira ocorrência da palavra "cadastrada por" no conteúdo da página
        match = site.find("span", string=re.compile("cadastrada por"))
        if match:
            # Encontra a tag pai que contém toda a informação
            parent_tag = match.find_parent("span", class_="B6fmyf")
            if parent_tag:
                # Extrai o nome entre "cadastrada por" e "sob o número"
                nome = parent_tag.text.split("cadastrada por ")[1].split(" sob o número")[0]
                return nome.strip()
    return "Nome não encontrado"

# Lista de códigos
codigos = [
    "MT-5103858-A5D392DF73984B7E8F2DF104C1D7F2CE",
    "MT-5106307-684CFDC4C60A4BDDA189B2EB2AB7C10E",
    "MT-5103858-BED9C95936414FA19B57D0438DCB29B4"
]

# Criar lista de tuplas (codigo, nome)
dados = [(codigo, obter_nome_por_codigo(codigo)) for codigo in codigos]

# Salvar em uma planilha
import pandas as pd

df = pd.DataFrame(dados, columns=["Código", "Nome"])
df.to_excel("nomes.xlsx", index=False)
